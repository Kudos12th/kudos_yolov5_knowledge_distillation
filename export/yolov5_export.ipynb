# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive

# %%
# !git clone https://github.com/Kudos12th/kudos_yolov5_knowledge_distillation.git
# Out:
# Cloning into 'kudos_yolov5_knowledge_distillation'...
# remote: Enumerating objects: 13005, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 13005 (delta 66), reused 144 (delta 66), pack-reused 12861
# Receiving objects: 100% (13005/13005), 140.96 MiB | 17.73 MiB/s, done.
# Resolving deltas: 100% (8609/8609), done.
# Updating files: 100% (190/190), done.

# %%
# %cd "/content/drive/MyDrive/kudos_yolov5_knowledge_distillation"
# Out:
# /content/drive/MyDrive/kudos_yolov5_knowledge_distillation

# %%
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
#파이토치 버전 확인, cuda device properties 확인
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.

# %%
# %pip install --upgrade --force-reinstall -r requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.41-py3-none-any.whl (196 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 68.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 10.4 MB/s eta 0:00:00
# ...
#   Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 66.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 22.3 MB/s eta 0:00:00
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 100.1 MB/s eta 0:00:00
# ...

# %%
# %pip install dill
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# %pip install --upgrade numpy

# %%
# %pip install pytorch2keras
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 48.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytorch2keras: filename=pytorch2keras-0.2.4-py3-none-any.whl size=29662 sha256=c889501ddf4ea6d390ab2a3ad2bbbc4a481a1eee0fe5040a795280cb71dee8bd
#   Stored in directory: /root/.cache/pip/wheels/24/cb/b8/bda24d11144e3be60f2881d8b95ed9c1ca8bb6aff4c898133a
# ...
#   Created wheel for onnx2keras: filename=onnx2keras-0.0.24-py3-none-any.whl size=24577 sha256=4518d704b4be74d820de44d91c48ad5004f6fce10523b1456974d20281fb0c4c
#   Stored in directory: /root/.cache/pip/wheels/a1/fb/c9/349c27912022d104c7dd5f5d272595c33b1b959c4468d5e784
# Successfully built pytorch2keras onnx2keras
# ...

# %%
# !PYTHONPATH=. python3 ./models/tf.py --weight ./kd_sn384_p2_ds/384sn_pretrained_2cfg_ds.pt --img 384
# Out:
# 2024-01-23 23:50:21.180358: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-23 23:50:21.180412: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-23 23:50:21.181901: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# models/tf: weights=/content/drive/MyDrive/kudos_yolov5_knowledge_distillation/kd_sn384_p2_ds/384sn_pretrained_2cfg_ds.pt, imgsz=[384, 384], batch_size=1, dynamic=False
# YOLOv5n summary: 214 layers, 1766623 parameters, 0 gradients, 4.2 GFLOPs
#
#                  from  n    params  module                                  arguments
# ...

# %%
# !python export.py --weights ./kd_sn384_p2_ds/384sn_pretrained_2cfg_ds.pt --include tfjs pb --int8 --img 384 --data ./data/data.yaml
# Out:
# export: data=./data/data.yaml, weights=['./kd_sn384_p2_ds/384sn_pretrained_2cfg_ds.pt'], imgsz=[384], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=True, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tfjs', 'pb']
# YOLOv5 🚀 6561216 Python-3.10.12 torch-2.1.2+cu121 CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from kd_sn384_p2_ds/384sn_pretrained_2cfg_ds.pt with output shape (1, 9072, 7) (3.6 MB)
# 2024-01-23 23:50:59.991861: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !pip uninstall numpy

# %%
# !pip install fastapi kaleido python-multipart uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
# ...
